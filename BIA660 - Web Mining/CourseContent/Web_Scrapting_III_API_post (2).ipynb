# %% [markdown]
# # <center>Web Scraping by API </center>

# %% [markdown]
# ## 1. Scrape data through APIs
# - Online content providers usually provide APIs for you to access data. Two types of APIs:
#    * Python packages: e.g. tweepy package from Twitter
#    * REST APIs: e.g. OMDB APIs (http://www.omdbapi.com), or TMDB (https://developers.themoviedb.org/3/getting-started)
# - You need to read documentation of APIs to figure out how to access data

# %% [markdown]
# ## 2. Scrape data by REST APIs (e.g. OMDB API)
# - A REST API is a web service that uses `HTTP` requests to `GET`, `PUT`, `POST` and `DELETE` data
# - Example:
#     - https://groceries.asda.com/api/items/search<font color="blue"><b>?</b></font><font color='green'><b>keyword</b></font>=<font color='red'><b>yogurt<b></font><front color='purple'><b>&</b></font><font color='green'><b>r</b></font>=<font color='red'><b>json<b></font>, where
#         - `?`: separate API endpoint  `https://groceries.asda.com/api/items/search` from parameters
#         - `keyword=yogurt`: search `yogurt` on parameter `keyword`
#         - `&`: combine multiple search criteria
#         - `r=json`: result is in json format
#     - You can directly paste the above API to your browser
#     - Or issue API calls using requests
# - You need to read API documentation to understand how to specify parameters

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import requests
import json
import pandas as pd

# %%
import requests
import json

keyword = 'yogurt'


url="https://groceries.asda.com/api/items/search?keyword=" + keyword + "&r=json"

print(url)

# invoke the API 
r = requests.get(url)

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    # json. dumps() function converts a Python object into a json string
    result = r.json()
    print (json.dumps(result, indent=4))
# Out:
# https://groceries.asda.com/api/items/search?keyword=yogurt&r=json
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "421",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_613f0638f04fd127608474cd^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362225",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228362",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245221",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.625",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#             "pricePerUOM": "",
#             "searchTuningScore": "3.650168E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203595",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "41",
#             "asdaSuggest": "",
#             "itemName": "Strawberry, Red Berry and Peach Flavour Yogurt",
#             "price": "\u00a30.95",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555677",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062467",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6829",
#             "name": "Frubes Strawberry, Red Berry and Peach Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555677",
#             "pricePerUOM": "",
#             "searchTuningScore": "2.3032004E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638102",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Vanilla Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446045",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453674",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Munch Bunch Double Up Strawberry & Vanilla Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446045",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.5264986E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3922315",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "62",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000786632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058338925",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6774",
#             "name": "Oykos Strawberry Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000786632",
#             "pricePerUOM": "",
#             "searchTuningScore": "5153373.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5207976",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "52",
#             "asdaSuggest": "",
#             "itemName": "Salted Caramel Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002079621",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360501437",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5962",
#             "name": "Oykos Salted Caramel Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002079621",
#             "pricePerUOM": "",
#             "searchTuningScore": "3571963.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362253",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "13",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Chocolate Balls & Banana Chocolate Flakes Yogurt",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228326",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "6x130g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500244811",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3077",
#             "name": "Muller Corner Vanilla Chocolate Balls & Banana Chocolate Flakes Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228326",
#             "pricePerUOM": "",
#             "searchTuningScore": "2217782.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2396629",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "152",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt Drinks",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "71431377",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.75",
#             "brandName": "Actimel",
#             "promoType": "Rollback",
#             "weight": "12x100",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058330868",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.625",
#             "name": "Actimel Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=71431377",
#             "pricePerUOM": "",
#             "searchTuningScore": "1412119.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362251",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Chocolate Digestive and Strawberry Shortcake Yogurts",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228426",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "6x130g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500244798",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.8571",
#             "name": "Muller Corner Chocolate Digestive and Strawberry Shortcake Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228426",
#             "pricePerUOM": "",
#             "searchTuningScore": "1337044.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2743850",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "184",
#             "asdaSuggest": "",
#             "itemName": "Multifruit Yogurt Drinks",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "81421582",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.75",
#             "brandName": "Actimel",
#             "promoType": "Rollback",
#             "weight": "12x100",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058331735",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6576",
#             "name": "Actimel Multifruit Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=81421582",
#             "pricePerUOM": "",
#             "searchTuningScore": "750283.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362239",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228322",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "143g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245092",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#             "pricePerUOM": "",
#             "searchTuningScore": "2.7807956E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362227",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228335",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245207",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.5",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228335",
#             "pricePerUOM": "",
#             "searchTuningScore": "2.4346584E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.7598638E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362229",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228313",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245146",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1429",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228313",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.752299E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362233",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228351",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245160",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228351",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.6357697E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Vanilla Yogurt & Granola",
#             "price": "\u00a30.90",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4211",
#             "name": "Activia Low Fat Vanilla Yogurt & Granola",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.2390727E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2857",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.1376015E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1111",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.1151944E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2206832",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Squashums Strawberry Yogurt Drinks",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "48537352",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "6x90g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "8410100200736",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1667",
#             "name": "Munch Bunch Squashums Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=48537352",
#             "pricePerUOM": "",
#             "searchTuningScore": "9346641.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203593",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "33",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Flavour Yogurt",
#             "price": "\u00a30.95",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062481",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4848",
#             "name": "Frubes Strawberry Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555632",
#             "pricePerUOM": "",
#             "searchTuningScore": "9230270.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582588",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Strawberry Yogurts",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285499",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500003",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.46",
#             "name": "Activia Intensely Creamy Strawberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285499",
#             "pricePerUOM": "",
#             "searchTuningScore": "7462899.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346366",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Vanilla & Dark Chocolate Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808389",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243616",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5556",
#             "name": "Muller Light Fat Free Vanilla & Dark Chocolate Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808389",
#             "pricePerUOM": "",
#             "searchTuningScore": "7290387.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3675692",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Raspberry Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000463345",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453926",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Munch Bunch Double Up Strawberry & Raspberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000463345",
#             "pricePerUOM": "",
#             "searchTuningScore": "5198420.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582592",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Cherry Yogurts",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285443",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500027",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Activia Intensely Creamy Cherry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285443",
#             "pricePerUOM": "",
#             "searchTuningScore": "5067112.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5705049",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "28",
#             "asdaSuggest": "",
#             "itemName": "6 Low Fat Red Fruit Yogurts",
#             "price": "\u00a30.85",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002962908",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA",
#             "promoType": "No Promo",
#             "weight": "6x125g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5054781337218",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1429",
#             "name": "ASDA 6 Low Fat Red Fruit Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002962908",
#             "pricePerUOM": "",
#             "searchTuningScore": "5024124.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786442",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "84",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Strawberry Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458097",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.10",
#             "brandName": "Petits Filous",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051584",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3333",
#             "name": "Petits Filous Raspberry & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458097",
#             "pricePerUOM": "",
#             "searchTuningScore": "4881207.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
# ...
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506128",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6098",
#             "name": "Activia Strawberry Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068084",
#             "pricePerUOM": "",
#             "searchTuningScore": "1676583.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6041546",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "32",
#             "asdaSuggest": "",
#             "itemName": "Cheesecake Inspired Whipped Greek Style Salted Caramel Yogurt",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000023135303",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner Bliss",
#             "promoType": "No Promo",
#             "weight": "4x100g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500227722",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.375",
#             "name": "Muller Corner Bliss Cheesecake Inspired Whipped Greek Style Salted Caramel Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000023135303",
#             "pricePerUOM": "",
#             "searchTuningScore": "1637864.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786440",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Apricot, Strawberry & Raspberry Yogurt",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458433",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Petits Filous",
#             "promoType": "No Promo",
#             "weight": "18x47g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051621",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.46",
#             "name": "Petits Filous Apricot, Strawberry & Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458433",
#             "pricePerUOM": "",
#             "searchTuningScore": "1549218.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286439451",
#             "shelfName": "Natural, Plain & Organic",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5035968",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "40",
#             "asdaSuggest": "",
#             "itemName": "Natural Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001817523",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Arla Skyr",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4016241030573",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.55",
#             "name": "Arla Skyr Natural Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "1215559958453",
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001817523",
#             "pricePerUOM": "",
#             "searchTuningScore": "1503357.6",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4714079",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Custard Low Fat Dessert",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001390198",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Rice",
#             "promoType": "No Promo",
#             "weight": "1x180g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183677",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8889",
#             "name": "Muller Rice Vanilla Custard Low Fat Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001390198",
#             "pricePerUOM": "",
#             "searchTuningScore": "1473081.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6677302",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Skyr Raspberry & Hazelnut Granola Yogurt",
#             "price": "\u00a31.20",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000206330953",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "180g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "4025500257576",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Muller Corner Skyr Raspberry & Hazelnut Granola Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000206330953",
#             "pricePerUOM": "",
#             "searchTuningScore": "1431212.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006858",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "1",
#             "asdaSuggest": "",
#             "itemName": "Red Fruits No Added Sugar Gut Health Yogurt",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067947",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "8x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506388",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Activia Red Fruits No Added Sugar Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067947",
#             "pricePerUOM": "",
#             "searchTuningScore": "1391975.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "341"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "22"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "21"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Fresh Food & Bakery",
#             "displayName": "Fresh Food & Bakery",
#             "itemCount": "16"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "7"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Health & Beauty",
#             "displayName": "Health & Beauty",
#             "itemCount": "3"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Frozen Food",
#             "displayName": "Frozen Food",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "75"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Light",
#             "displayName": "Muller Light",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Corner",
#             "displayName": "Muller Corner",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yazoo",
#             "displayName": "Yazoo",
#             "itemCount": "10"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 34,
#     "statusCode": "0"
# }

# %%
# Exercise 2.2.  Another way to pass parameters

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# in case authentication is needed, use
# r = requests.get('https://api.github.com/user', \
# auth=('user', 'pass'))

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    print (json.dumps(r.json(), indent=4))
# Out:
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "isHookLogicInsert": "false",
#     "totalResult": "419",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "7",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_613f0638f04fd127608474cd^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362225",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228362",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245221",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.625",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#             "pricePerUOM": "",
#             "searchTuningScore": "2.8751692E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203595",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "41",
#             "asdaSuggest": "",
#             "itemName": "Strawberry, Red Berry and Peach Flavour Yogurt",
#             "price": "\u00a30.95",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555677",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062467",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6829",
#             "name": "Frubes Strawberry, Red Berry and Peach Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555677",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.7800482E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638102",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Vanilla Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446045",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453674",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Munch Bunch Double Up Strawberry & Vanilla Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446045",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.4810072E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3922315",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "61",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000786632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058338925",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7049",
#             "name": "Oykos Strawberry Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000786632",
#             "pricePerUOM": "",
#             "searchTuningScore": "4545069.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5207976",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "52",
#             "asdaSuggest": "",
#             "itemName": "Salted Caramel Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002079621",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360501437",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5962",
#             "name": "Oykos Salted Caramel Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002079621",
#             "pricePerUOM": "",
#             "searchTuningScore": "3152679.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362253",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "13",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Chocolate Balls & Banana Chocolate Flakes Yogurt",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228326",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "6x130g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500244811",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3077",
#             "name": "Muller Corner Vanilla Chocolate Balls & Banana Chocolate Flakes Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228326",
#             "pricePerUOM": "",
#             "searchTuningScore": "1830526.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2396629",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "151",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt Drinks",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "71431377",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.75",
#             "brandName": "Actimel",
#             "promoType": "Rollback",
#             "weight": "12x100",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058330868",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6225",
#             "name": "Actimel Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=71431377",
#             "pricePerUOM": "",
#             "searchTuningScore": "1250348.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362251",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "6",
#             "asdaSuggest": "",
#             "itemName": "Chocolate Digestive and Strawberry Shortcake Yogurts",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228426",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "6x130g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500244798",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Chocolate Digestive and Strawberry Shortcake Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228426",
#             "pricePerUOM": "",
#             "searchTuningScore": "1093817.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2743850",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "184",
#             "asdaSuggest": "",
#             "itemName": "Multifruit Yogurt Drinks",
#             "price": "\u00a32.85",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "81421582",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.75",
#             "brandName": "Actimel",
#             "promoType": "Rollback",
#             "weight": "12x100",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058331735",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6576",
#             "name": "Actimel Multifruit Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=81421582",
#             "pricePerUOM": "",
#             "searchTuningScore": "664819.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362239",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228322",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "143g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245092",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#             "pricePerUOM": "",
#             "searchTuningScore": "2.2075024E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362227",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228335",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245207",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.5",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228335",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.923606E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.3840079E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362229",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228313",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245146",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1429",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228313",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.3501813E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362233",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228351",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245160",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Muller Corner Strawberry Yogurt with White Chocolate Shortcake Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228351",
#             "pricePerUOM": "",
#             "searchTuningScore": "1.2898824E7",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Vanilla Yogurt & Granola",
#             "price": "\u00a30.90",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4211",
#             "name": "Activia Low Fat Vanilla Yogurt & Granola",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "9565623.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2857",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "9001350.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1111",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "8942990.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2206832",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Squashums Strawberry Yogurt Drinks",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "48537352",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "6x90g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "8410100200736",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1667",
#             "name": "Munch Bunch Squashums Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=48537352",
#             "pricePerUOM": "",
#             "searchTuningScore": "8771336.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203593",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "33",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Flavour Yogurt",
#             "price": "\u00a30.95",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062481",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4848",
#             "name": "Frubes Strawberry Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555632",
#             "pricePerUOM": "",
#             "searchTuningScore": "7405466.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582588",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Strawberry Yogurts",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285499",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500003",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.46",
#             "name": "Activia Intensely Creamy Strawberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285499",
#             "pricePerUOM": "",
#             "searchTuningScore": "6224355.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346366",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Vanilla & Dark Chocolate Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808389",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243616",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5556",
#             "name": "Muller Light Fat Free Vanilla & Dark Chocolate Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808389",
#             "pricePerUOM": "",
#             "searchTuningScore": "5740793.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3675692",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Raspberry Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000463345",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453926",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.6667",
#             "name": "Munch Bunch Double Up Strawberry & Raspberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000463345",
#             "pricePerUOM": "",
#             "searchTuningScore": "5057318.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5705049",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "28",
#             "asdaSuggest": "",
#             "itemName": "6 Low Fat Red Fruit Yogurts",
#             "price": "\u00a30.85",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002962908",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "ASDA",
#             "promoType": "No Promo",
#             "weight": "6x125g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5054781337218",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.1429",
#             "name": "ASDA 6 Low Fat Red Fruit Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002962908",
#             "pricePerUOM": "",
#             "searchTuningScore": "4288248.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582592",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Cherry Yogurts",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285443",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500027",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Activia Intensely Creamy Cherry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285443",
#             "pricePerUOM": "",
#             "searchTuningScore": "4057737.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4582596",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "50",
#             "asdaSuggest": "",
#             "itemName": "Intensely Creamy Peach Yogurts",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001285082",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360500041",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.76",
#             "name": "Activia Intensely Creamy Peach Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001285082",
#             "pricePerUOM": "",
#             "searchTuningScore": "3824266.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
# ...
#             "id": "976012",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5410146407024",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6225",
#             "name": "Actimel Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=976012",
#             "pricePerUOM": "",
#             "searchTuningScore": "1469921.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006858",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "1",
#             "asdaSuggest": "",
#             "itemName": "Red Fruits No Added Sugar Gut Health Yogurt",
#             "price": "\u00a33.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067947",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "8x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506388",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Activia Red Fruits No Added Sugar Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067947",
#             "pricePerUOM": "",
#             "searchTuningScore": "1383270.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4714077",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Original Low Fat Dessert",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001390020",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Rice",
#             "promoType": "No Promo",
#             "weight": "1x180g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183646",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.75",
#             "name": "Muller Rice Original Low Fat Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001390020",
#             "pricePerUOM": "",
#             "searchTuningScore": "1367276.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215640038591",
#             "shelfName": "High In Protein",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033892",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "16",
#             "asdaSuggest": "",
#             "itemName": "Blueberry Yogurt",
#             "price": "\u00a30.98",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001812976",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018028",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.5625",
#             "name": "Arla Protein Blueberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001812976",
#             "pricePerUOM": "",
#             "searchTuningScore": "1330508.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7050994",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "3",
#             "asdaSuggest": "",
#             "itemName": "Limited Edition Pineapple Yogurts",
#             "price": "\u00a32.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000300501540",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "New",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506814",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Activia Limited Edition Pineapple Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000300501540",
#             "pricePerUOM": "",
#             "searchTuningScore": "1214052.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4138877",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "20",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Greek Style Strawberry Yogurts",
#             "price": "\u00a31.75",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000944384",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "4x120g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500173616",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.5",
#             "name": "Muller Light Fat Free Greek Style Strawberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000944384",
#             "pricePerUOM": "",
#             "searchTuningScore": "1191101.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "10::for::\u00a33.5::true",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4714079",
#             "promoDetailFull": "10 for \u00a33.5",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Custard Low Fat Dessert",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001390198",
#             "promoId": "ls91195",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Rice",
#             "promoType": "No Promo",
#             "weight": "1x180g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "10",
#             "promoValue": "\u00a33.50",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183677",
#             "promoDetail": "10 for \u00a33.5",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.875",
#             "name": "Muller Rice Vanilla Custard Low Fat Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001390198",
#             "pricePerUOM": "",
#             "searchTuningScore": "1146806.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "340"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "21"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "21"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Fresh Food & Bakery",
#             "displayName": "Fresh Food & Bakery",
#             "itemCount": "16"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "9"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "7"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Health & Beauty",
#             "displayName": "Health & Beauty",
#             "itemCount": "3"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Frozen Food",
#             "displayName": "Frozen Food",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "75"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Light",
#             "displayName": "Muller Light",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Corner",
#             "displayName": "Muller Corner",
#             "itemCount": "12"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yazoo",
#             "displayName": "Yazoo",
#             "itemCount": "10"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 35,
#     "statusCode": "0"
# }

# %% [markdown]
# ## 3. JSON (JavaScript Object Notation)
#
# ### What is JSON
# - A lightweight data-interchange format
# - "Self-describing" and easy to understand
# - JSON format is text only
# - Language independent: can be read and used as a data format by any programming language
#
# ###  JSON Syntax Rules
# JSON syntax is derived from JavaScript object notation syntax:
# - Data is in **name/value** pairs separated by commas
# - Curly braces hold objects
# - Square brackets hold arrays
#
# ### A JSON object is:
# - **a dictionary** or
# - a **list of dictionaries**
#
# ### Useful JSON functions
# - dumps: save json object to string
# - dump: save json object to file
# - loads: load from a string in json format
# - load: load from a file in json format

# %%
# Exercise 3.1 API returns a JSON object 

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# if the API call returns a successful response
if r.status_code==200:
    result = r.json()
    
    df = pd.DataFrame(result["items"])
    df.head()
# Out:
#          shelfId     shelfName         deptId            deptName isBundle  \
# 0  1215286383583       Corners  1215341888021  Yogurts & Desserts    false
# 1   910000976085  Kids Yogurts  1215341888021  Yogurts & Desserts    false
# 2   910000976085  Kids Yogurts  1215341888021  Yogurts & Desserts    false
# 3  1215639963408   Greek Style  1215341888021  Yogurts & Desserts    false
# 4  1215639963408   Greek Style  1215341888021  Yogurts & Desserts    false
#
#     meatStickerDetails extraLargeImageURL bundledItemCount  \
# 0  10::for::£3.5::true                                   0
# 1                                                        0
# 2                                                        0
# 3                                                        0
# 4                                                        0
#
#                            scene7Host      cin  ... avgWeight  \
# 0  https://ui.assets-asda.com:443/dm/  6362225  ...
# 1  https://ui.assets-asda.com:443/dm/  6203595  ...
# 2  https://ui.assets-asda.com:443/dm/  3638102  ...
# 3  https://ui.assets-asda.com:443/dm/  3922315  ...
# 4  https://ui.assets-asda.com:443/dm/  5207976  ...
#
#                                          iconDetails maxQty pricePerWt  \
# 0  {'promotionalIcons': ['59600049'], 'informatio...   10.0       Each
# 1  {'promotionalIcons': ['45100001', '59600050'],...   10.0       Each
# 2  {'promotionalIcons': ['59600051'], 'informatio...   10.0       Each
# 3                                                 {}   10.0       Each
# 4                                                 {}   10.0       Each
#
#                                           productURL pricePerUOM  \
# 0  https://groceries.asda.com:443/api/items/view?...
# 1  https://groceries.asda.com:443/api/items/view?...
# 2  https://groceries.asda.com:443/api/items/view?...
# 3  https://groceries.asda.com:443/api/items/view?...
# 4  https://groceries.asda.com:443/api/items/view?...
#
#   searchTuningScore onSale salePrice positionChngByMargin
# 0       2.8751692E7  False                              0
# 1       1.7800482E7  False                              0
# 2       1.4810072E7  False                              0
# 3         4545069.5  False                              0
# 4         3152679.5  False                              0
#
# [5 rows x 45 columns]

# %%
# Exercise 3.2. Parse JSON object (a dictionary)

# convert the first 2 items to string
s = json.dumps(result["items"][0:2], indent=4)
print(s)

# load back from a string
items = json.loads(s)
items

# save to file
json.dump(result["items"], open("items.json","w"))

# load back from file
items = json.load(open("items.json","r"))
print("test loaded data\n")
len(items)
items[0]
# Out:
# [
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "10::for::\u00a33.5::true",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "6362225",
#         "promoDetailFull": "10 for \u00a33.5",
#         "availability": "A",
#         "totalReviewCount": "8",
#         "asdaSuggest": "",
#         "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#         "price": "\u00a30.55",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000120228362",
#         "promoId": "ls91195",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller Corner",
#         "promoType": "No Promo",
#         "weight": "130g",
#         "promoOfferTypeCode": "15",
#         "promoQty": "10",
#         "promoValue": "\u00a33.50",
#         "productAttribute": "",
#         "scene7AssetId": "4025500245221",
#         "promoDetail": "10 for \u00a33.5",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.625",
#         "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#         "avgWeight": "",
#         "iconDetails": {
#             "promotionalIcons": [
#                 "59600049"
#             ],
#             "informationalIcons": []
#         },
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#         "pricePerUOM": "",
#         "searchTuningScore": "2.8751692E7",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     },
#     {
#         "shelfId": "910000976085",
#         "shelfName": "Kids Yogurts",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "6203595",
#         "promoDetailFull": "",
#         "availability": "A",
#         "totalReviewCount": "41",
#         "asdaSuggest": "",
#         "itemName": "Strawberry, Red Berry and Peach Flavour Yogurt",
#         "price": "\u00a30.95",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000078555677",
#         "promoId": "",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "\u00a31.00",
#         "brandName": "Frubes",
#         "promoType": "Rollback",
#         "weight": "9x37g",
#         "promoOfferTypeCode": "",
#         "promoQty": "",
#         "promoValue": "",
#         "productAttribute": "",
#         "scene7AssetId": "3329770062467",
#         "promoDetail": "",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.6829",
#         "name": "Frubes Strawberry, Red Berry and Peach Flavour Yogurt",
#         "avgWeight": "",
#         "iconDetails": {
#             "promotionalIcons": [
#                 "45100001",
#                 "59600050"
#             ],
#             "informationalIcons": []
#         },
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555677",
#         "pricePerUOM": "",
#         "searchTuningScore": "1.7800482E7",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     }
# ]
# test loaded data
# {'shelfId': '1215286383583',
#  'shelfName': 'Corners',
#  'deptId': '1215341888021',
#  'deptName': 'Yogurts & Desserts',
#  'isBundle': 'false',
#  'meatStickerDetails': '10::for::£3.5::true',
#  'extraLargeImageURL': '',
#  'bundledItemCount': '0',
#  'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#  'cin': '6362225',
#  'promoDetailFull': '10 for £3.5',
#  'availability': 'A',
#  'totalReviewCount': '8',
#  'asdaSuggest': '',
#  'itemName': 'Vanilla Yogurt with Chocolate\xa0Balls',
#  'price': '£0.55',
#  'imageURL': '',
#  'aisleName': 'Yogurts & Fromage Frais',
#  'id': '1000120228362',
#  'promoId': 'ls91195',
#  'isFavourite': 'false',
#  'hasAlternates': 'false',
#  'wasPrice': '',
#  'brandName': 'Muller Corner',
#  'promoType': 'No Promo',
#  'weight': '130g',
#  'promoOfferTypeCode': '15',
#  'promoQty': '10',
#  'promoValue': '£3.50',
#  'productAttribute': '',
#  'scene7AssetId': '4025500245221',
#  'promoDetail': '10 for £3.5',
#  'bundleDiscount': '0.00',
#  'avgStarRating': '4.625',
#  'name': 'Muller Corner Vanilla Yogurt with Chocolate\xa0Balls',
#  'avgWeight': '',
#  'iconDetails': {'promotionalIcons': ['59600049'], 'informationalIcons': []},
#  'maxQty': '10.0',
#  'pricePerWt': 'Each',
#  'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000120228362',
#  'pricePerUOM': '',
#  'searchTuningScore': '2.8751692E7',
#  'onSale': False,
#  'salePrice': '',
#  'positionChngByMargin': 0}

# %% [markdown]
# ## 4. Get Tweets
#
# Reference:
# - https://github.com/scalto/snscrape-by-location/blob/main/snscrape_by_location_tutorial.ipynb
# - https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25
#
# Note: User object is not exposed by TwitterSearchScraper any more.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#  search by keywords + time
# TwitterSearchScraper returns an interator, islice loops through the iterator

df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"blockchain + since:2020-10-31 until:2020-11-03"').get_items(), 500))

print(len(df))
df.head()
# Out:
# 500
#                                                  url  \
# 0  https://twitter.com/zawphyowai199/status/13234...
# 1  https://twitter.com/CryptoWatchBot/status/1323...
# 2  https://twitter.com/Rayinhosen/status/13234145...
# 3  https://twitter.com/coinmarketnet/status/13234...
# 4  https://twitter.com/Link_Errors/status/1323414...
#
#                        date  \
# 0 2020-11-02 23:59:55+00:00
# 1 2020-11-02 23:59:53+00:00
# 2 2020-11-02 23:59:46+00:00
# 3 2020-11-02 23:59:43+00:00
# 4 2020-11-02 23:59:42+00:00
#
#                                              content                   id  \
# 0  Synic Token Airdrop is now Live🚀💰🏆\n\nClick on...  1323414568236806146
# 1  @NEO_Blockchain, #NEO is the coin with the bes...  1323414560204824576
# 2  📌 CPX Airdrop is Live, 🎁 Join to get Free 7 CP...  1323414530769051648
# 3  📌 CPX Airdrop is Live, 🎁 Join to get Free 7 CP...  1323414518651781120
# 4  Yearnify Finance Airdrop is now Live🚀💰🏆\n\nCli...  1323414512675016706
#
#          username                                           outlinks  \
# 0   zawphyowai199       [https://t.me/synictoken_officialAirdropbot]
# 1  CryptoWatchBot                                                 []
# 2      Rayinhosen  [https://t.me/CrypxieAirdrop_bot?start=r017400...
# 3   coinmarketnet  [https://t.me/CrypxieAirdrop_bot?start=r076622...
# 4     Link_Errors                  [https://t.me/YearnifyAirdropBot]
#
#                                           outlinksss  \
# 0         https://t.me/synictoken_officialAirdropbot
# 1
# 2  https://t.me/CrypxieAirdrop_bot?start=r0174001...
# 3  https://t.me/CrypxieAirdrop_bot?start=r0766228434
# 4                    https://t.me/YearnifyAirdropBot
#
#                  tcooutlinks            tcooutlinksss
# 0  [https://t.co/O83hXYOniH]  https://t.co/O83hXYOniH
# 1                         []
# 2  [https://t.co/dcfBIyNYi4]  https://t.co/dcfBIyNYi4
# 3  [https://t.co/Ff0IdY5i1G]  https://t.co/Ff0IdY5i1G
# 4  [https://t.co/6HpZOBOZzI]  https://t.co/6HpZOBOZzI

# %%
# search by user

df = pd.DataFrame(itertools.islice(sntwitter.TwitterUserScraper(
    '"zawphyowai199"').get_items(), 500))

print(len(df))
df.tail()
# Out:
# 500
#                                                    url  \
# 495  https://twitter.com/zawphyowai199/status/13669...
# 496  https://twitter.com/zawphyowai199/status/13669...
# 497  https://twitter.com/zawphyowai199/status/13667...
# 498  https://twitter.com/zawphyowai199/status/13667...
# 499  https://twitter.com/zawphyowai199/status/13667...
#
#                          date  \
# 495 2021-03-03 02:51:11+00:00
# 496 2021-03-03 02:47:55+00:00
# 497 2021-03-02 14:55:21+00:00
# 498 2021-03-02 14:51:58+00:00
# 499 2021-03-02 11:50:32+00:00
#
#                                                content                   id  \
# 495  @airdropinspect @Ashwsbreal @blazingbitcoin @m...  1366944211526819840
# 496  @alexanhtuan #Phoswapper\n\n@mma728122 \n@mst5...  1366943388881154048
# 497  @KoalaDefi @dfgr5eytsy56es1 @paisalnurpadil1 @...  1366764068342751238
# 498  @BSCToolzApp Very good Project. I recommend.\n...  1366763216978731008
# 499  @RocketGameVip @mma728122 \n@mst5792 \n@wt7276...  1366717558095835137
#
#           username outlinks outlinksss tcooutlinks tcooutlinksss
# 495  zawphyowai199       []                     []
# 496  zawphyowai199       []                     []
# 497  zawphyowai199       []                     []
# 498  zawphyowai199       []                     []
# 499  zawphyowai199       []                     []

# %% [markdown]
# ## 5. Tweepy
# - Tweepy is a python library to access Twitter API.
# - `pip install tweepy`
# - The Tweepy documentation has detailed explanations: https://docs.tweepy.org/en/stable/
# - You need to apply for a developer account from here: https://developer.twitter.com/en/apply-for-access

# %%
import tweepy
import csv
import datetime

# https://docs.tweepy.org/en/stable/auth_tutorial.html

# enter your account information
CONSUMER_KEY=''
CONSUMER_SECRET=''
ACCESS_KEY=''
ACCESS_SECRET=''

auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
api=tweepy.API(auth)

# %%
# Take a look at the public tweets from your account's home timeline 

public_tweets = api.home_timeline()
for tweet in public_tweets[:2]:
    print(tweet.text)
# Out:
# How did your neighborhood vote in the California recall election?
#
# Explore the latest precinct results from Los Ang… https://t.co/cdJRQzUbpU
# A new fence, an information-sharing alert and ramped-up airport security are just a few of the ways law enforcement… https://t.co/cYps7sbW7A

# %%
# is this useful information?
# Let's take a close look at ONE tweet json

public_tweets[0]
# there's no way to figure this out
# Out:
# Status(_api=<tweepy.api.API object at 0x7fe63da41d50>, _json={'created_at': 'Fri Sep 17 15:22:52 +0000 2021', 'id': 1438886178594324480, 'id_str': '1438886178594324480', 'text': 'How did your neighborhood vote in the California recall election?\n\nExplore the latest precinct results from Los Ang… https://t.co/cdJRQzUbpU', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cdJRQzUbpU', 'expanded_url': 'https://twitter.com/i/web/status/1438886178594324480', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16664681, 'id_str': '16664681', 'name': 'Los Angeles Times', 'screen_name': 'latimes', 'location': 'El Segundo, CA', 'description': 'Covering the world with a West Coast perspective. Subscribe now: https://t.co/6Kr8lqVIMd  Write to us: letters@latimes.com', 'url': 'https://t.co/WeffKZ2O0l', 'entities': {'url': {'urls': [{'url': 'https://t.co/WeffKZ2O0l', 'expanded_url': 'http://latimes.com', 'display_url': 'latimes.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/6Kr8lqVIMd', 'expanded_url': 'http://latimes.com/subscribe', 'display_url': 'latimes.com/subscribe', 'indices': [65, 88]}]}}, 'protected': False, 'followers_count': 3811173, 'friends_count': 7057, 'listed_count': 34817, 'created_at': 'Thu Oct 09 11:07:42 +0000 2008', 'favourites_count': 3100, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 378448, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1372216202819346434/v6Qz0D8h_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1372216202819346434/v6Qz0D8h_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16664681/1609354452', 'profile_link_color': '009999', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '615F61', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 9, 17, 15, 22, 52), id=1438886178594324480, id_str='1438886178594324480', text='How did your neighborhood vote in the California recall election?\n\nExplore the latest precinct results from Los Ang… https://t.co/cdJRQzUbpU', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cdJRQzUbpU', 'expanded_url': 'https://twitter.com/i/web/status/1438886178594324480', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7fe63da41d50>, _json={'id': 16664681, 'id_str': '16664681', 'name': 'Los Angeles Times', 'screen_name': 'latimes', 'location': 'El Segundo, CA', 'description ...

# %%
# make it look better
# convert to string
json_str = json.dumps(public_tweets[0]._json)

# deserialise string into python object
parsed = json.loads(json_str)

print(json.dumps(parsed, indent=4, sort_keys=True))
# Now we can have a better idea of the clustered relations of the json object
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 17 15:22:52 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1438886178594324480",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/cdJRQzUbpU"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 1,
#     "favorited": false,
#     "geo": null,
#     "id": 1438886178594324480,
#     "id_str": "1438886178594324480",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "text": "How did your neighborhood vote in the California recall election?\n\nExplore the latest precinct results from Los Ang\u2026 https://t.co/cdJRQzUbpU",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Oct 09 11:07:42 +0000 2008",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Covering the world with a West Coast perspective. Subscribe now: https://t.co/6Kr8lqVIMd  Write to us: letters@latimes.com",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "latimes.com/subscribe",
#                         "expanded_url": "http://latimes.com/subscribe",
#                         "indices": [
#                             65,
#                             88
#                         ],
#                         "url": "https://t.co/6Kr8lqVIMd"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "latimes.com",
#                         "expanded_url": "http://latimes.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/WeffKZ2O0l"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 3100,
#         "follow_request_sent": false,
#         "followers_count": 3811173,
#         "following": true,
#         "friends_count": 7057,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 16664681,
#         "id_str": "16664681",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 34817,
#         "location": "El Segundo, CA",
#         "name": "Los Angeles Times",
#         "notifications": false,
#         "profile_background_color": "FFFFFF",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme16/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/16664681/1609354452",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1372216202819346434/v6Qz0D8h_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1372216202819346434/v6Qz0D8h_normal.jpg",
#         "profile_link_color": "009999",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "615F61",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "latimes",
#         "statuses_count": 378448,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "https://t.co/WeffKZ2O0l",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %% [markdown]
# ### 5.1. Get tweets from users' timeline
# - Make a Timeline call to retrieve the most recent 3200 tweets by a user (a rule set by Twitter).
#     - Note: the time range you get depends on how often the user posts tweets.
# - Parameters for the timeline call
#     - `count`: the number of results to try and retrieve per page. Maximum is 200.
#     - Make multiple calls to retrieve the 3200 tweets.
#     - `tweet_mode`:swaps the text index for full_text, and prevents a primary tweet longer than 140 characters from being truncated.
# - Variables of tweet objects
#     - https://docs.tweepy.org/en/stable/api.html#tweepy-api-twitter-api-wrapper

# %%
# Get the first five tweets of a user.
timeline = api.user_timeline("KelloggCompany",count=5,tweet_mode="extended")

for status in timeline:
    print (status.id)
    print (status.full_text)
# Out:
# 1438671732513116163
# RT @toendhunger: In the fight against #hunger, #schoolmeals are a critical investment in the next generation. Check out our recent webinar…
# 1438605434030600203
# Proud to join @AlbertsonsCos to fight childhood hunger. Kellogg will commit $120,000 to @nokidhungry and @AlbertsonsCos foundation Nourishing Neighbors #BetterDays https://t.co/9AAMWecFpS
# 1438584502574452746
# Land a Gr-r-reat internship with Kellogg’s #internship recruiting virtual event #employee https://t.co/ilgnrdfhQs
# 1438535106591961090
# RT @MidwestRowCrop: What can member companies do together to advance regenerative agriculture? Here’s what Oliver Morton, Chief Customer Of…
# 1438164431322636294
# “The truck drivers we work with are the best in the business. They are critical to our supply chain running successfully. We appreciate all they do!” – Matt Rose Sr. Dir., Kellogg North America Transportation #ThankATrucker #NTDAW2021 https://t.co/5bSABzeWLV

# %%
# Step 1: get a list of tweets 
# Step 2: extract the varaibles you want

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth)
    
    # initialize the first call
    alltweets=[]
    new_tweets=api.user_timeline(user_name, count=200)
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  #next time start from the oldest one minus one 
    
    # continue to get tweets
    while len(new_tweets)>0:  
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
    
    # extract the variables you want
    outtweets = [[tweet.id_str, tweet.user.name, tweet.created_at, tweet.user.followers_count,
                  tweet.text.encode("utf-8")] for tweet in alltweets]
            
    # write out your variables
    with open('%s_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","user_name","created_at","followers","text"])
        writer.writerows(outtweets)
    pass

# use your function
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1381701008527605762
# ...400 tweets downloaded so far
# getting tweets before 1315649082661236735
# ...600 tweets downloaded so far
# getting tweets before 1245073331252068353
# ...800 tweets downloaded so far
# getting tweets before 1176214453777588224
# ...1000 tweets downloaded so far
# getting tweets before 1103676050536628223
# ...1200 tweets downloaded so far
# getting tweets before 1009496869305712639
# ...1400 tweets downloaded so far
# getting tweets before 936346653279379455
# ...1600 tweets downloaded so far
# getting tweets before 877615558744735745
# ...1800 tweets downloaded so far
# getting tweets before 827194028668108801
# ...2000 tweets downloaded so far
# getting tweets before 764075619474735103
# ...2197 tweets downloaded so far
# getting tweets before 707276031858753536
# ...2395 tweets downloaded so far
# getting tweets before 656861069776920575
# ...2594 tweets downloaded so far
# getting tweets before 604011239203819519
# ...2794 tweets downloaded so far
# getting tweets before 525294112875237375
# ...2992 tweets downloaded so far
# getting tweets before 449241568768049151
# ...3192 tweets downloaded so far
# getting tweets before 335091149431767039
# ...3196 tweets downloaded so far
# getting tweets before 335089662253207551
# ...3196 tweets downloaded so far

# %%
# Take a look at the table you got
df= pd.read_csv('KelloggCompany_tweet.csv', header=0)
df.head()

# how many tweets we get?
len(df)

# The first tweet is a retweet. Take a look at the text.
df.text[0]

# Let's compare it with the actual tweet. 
# You can find each tweet by its ID. 
# https://twitter.com/KelloggCompany/status/1438671732513116163
# Out:
#                     id        user_name           created_at  followers  \
# 0  1438671732513116163  Kellogg Company  2021-09-17 01:10:44      76099
# 1  1438605434030600203  Kellogg Company  2021-09-16 20:47:18      76099
# 2  1438584502574452746  Kellogg Company  2021-09-16 19:24:07      76099
# 3  1438535106591961090  Kellogg Company  2021-09-16 16:07:50      76099
# 4  1438164431322636294  Kellogg Company  2021-09-15 15:34:54      76099
#
#                                                 text
# 0  b'RT @toendhunger: In the fight against #hunge...
# 1  b'Proud to join @AlbertsonsCos to fight childh...
# 2  b'Land a Gr-r-reat internship with Kellogg\xe2...
# 3  b'RT @MidwestRowCrop: What can member companie...
# 4  b'\xe2\x80\x9cThe truck drivers we work with a...
# 3196
# "b'RT @toendhunger: In the fight against #hunger, #schoolmeals are a critical investment in the next generation. Check out our recent webinar\\xe2\\x80\\xa6'"

# %% [markdown]
# ### 5.2. Deal with truncated text
# - For text mining on Twitter, it is important to get the full text.
#     - Full text would be essential for topic modeling and sentiment analysis.
#     - Full text is also important for extracting mention networks (note the previous example).
# - Use the `tweet_mode="extended"` when calling a user's timeline.
#     - When using extended mode, the `text` attribute of Status objects returned is replaced by a `full_text` attribute, which contains the entire untruncated text of the Tweet.
# - Full text for tweets that are retweets.
#     - If the tweet is a retweet, the full_text is still truncated.
#     - We need to access the full text through `retweeted_status` attribute, which is a status object itself.
# - For reference: https://docs.tweepy.org/en/stable/extended_tweets.html

# %%
# Let's deal with retweets

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth,wait_on_rate_limit=True)

    alltweets=[]
    new_tweets=api.user_timeline(user_name, count=200,tweet_mode="extended")
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  
    
    # set date condition
    startDate=datetime.datetime(2021, 1, 1, 0, 0, 0)
    while new_tweets[-1].created_at > startDate:
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
        
    # check if it's a retweet
    # When using extended mode with a Retweet, the full_text attribute of the Status object may be truncated    
    # However, since the retweeted_status attribute (of a Status object that is a Retweet) is itself a Status object
    # the full_text attribute of the Retweeted Status object can be used instead.
    
    outtweets_all=[]
    for tweet in alltweets:
        status = api.get_status(tweet.id, tweet_mode="extended")
        
        if hasattr(status, "retweeted_status"):  # is a retweet
            full_text=status.retweeted_status.full_text.encode("utf-8")
            
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            tweet.retweeted_status.user.name,tweet.retweeted_status.user.screen_name,tweet.retweeted_status.user.description]
            outtweets_all.append(outtweets)
  
        else: # not a retweet
            full_text=status.full_text.encode("utf-8")
                    
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            "no value","no value","no value"]
            outtweets_all.append(outtweets)

    with open('%s_full_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","created_at","full_text",
                        "user.name","user.screen_name","user.followers_count",
                        "retweeted_status.user.name","retweeted_status.user.screen_name","retweeted_status.user.description"])
        writer.writerows(outtweets_all)

        
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1381701008527605762
# ...400 tweets downloaded so far

# %%
df= pd.read_csv('KelloggCompany_full_tweet.csv', header=0)
df.head()
len(df)
# plese compare this full text with the above truncated text, what differences can you find?
df.full_text[0]
# Out:
#                     id           created_at  \
# 0  1438671732513116163  2021-09-17 01:10:44
# 1  1438605434030600203  2021-09-16 20:47:18
# 2  1438584502574452746  2021-09-16 19:24:07
# 3  1438535106591961090  2021-09-16 16:07:50
# 4  1438164431322636294  2021-09-15 15:34:54
#
#                                            full_text        user.name  \
# 0  b'In the fight against #hunger, #schoolmeals a...  Kellogg Company
# 1  b'Proud to join @AlbertsonsCos to fight childh...  Kellogg Company
# 2  b'Land a Gr-r-reat internship with Kellogg\xe2...  Kellogg Company
# 3  b'What can member companies do together to adv...  Kellogg Company
# 4  b'\xe2\x80\x9cThe truck drivers we work with a...  Kellogg Company
#
#   user.screen_name  user.followers_count      retweeted_status.user.name  \
# 0   KelloggCompany                 76099          Alliance To End Hunger
# 1   KelloggCompany                 76099                        no value
# 2   KelloggCompany                 76099                        no value
# 3   KelloggCompany                 76099  Midwest Row Crop Collaborative
# 4   KelloggCompany                 76099                        no value
#
#   retweeted_status.user.screen_name  \
# 0                       toendhunger
# 1                          no value
# 2                          no value
# 3                    MidwestRowCrop
# 4                          no value
#
#                    retweeted_status.user.description
# 0  Building the will to #EndHunger at home and ab...
# 1                                           no value
# 2                                           no value
# 3  A coalition of leading companies and NGOs driv...
# 4                                           no value
# 400
# "b'In the fight against #hunger, #schoolmeals are a critical investment in the next generation. Check out our recent webinar with @WFPUSA, @KelloggCompany, and @GCNFoundation. https://t.co/XLh0i39iwV'"

# %% [markdown]
# ### 5.3. Build Twitter networks
# - **Follower-followee network**
#     - If you have a list of user accounts, you may retrive the pairwise boolean values of following relations.
#     - Parameters
#         * `source_id` – The user_id of the subject user.
#         * `source_screen_name` – The screen_name of the subject user.
#         * `target_id` – The user_id of the target user.
#         * `target_screen_name` – The screen_name of the target user.
# - **Retweet network**
#     - Retweeted accounts can be extracted while scraping the API.
#     - Or retweeted accounts can be extracted from the text.
# - **Mention network**
#     - Can be extracted from the full text.

# %%
# How to scrape the follower-followee network?
# we can directly retrieve a bollean value 

dog="Microsoft"
cat="Oracle"

is_following = api.show_friendship(source_screen_name=dog,target_screen_name=cat)
print(is_following[1].following)

# Question: how to get the adjacency matrix of a follower-followee network?
# Out:
# True

# %% [markdown]
# ##### Twitter data resources
# https://github.com/echen102/us-pres-elections-2020 <br>
# https://github.com/echen102/COVID-19-TweetIDs
